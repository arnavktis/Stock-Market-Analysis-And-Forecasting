# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
apple = pd.read_csv('Assets/AAPL.csv')
apple.drop('Day Difference', inplace=True, axis=1) 
apple.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close       Volume
# 0  12-12-1980  0.128348  0.128906  0.128348  0.128348   0.099450  469033600.0
# 1  15-12-1980  0.122210  0.122210  0.121652  0.121652   0.094261  175884800.0
# 2  16-12-1980  0.113281  0.113281  0.112723  0.112723   0.087343  105728000.0
# 3  17-12-1980  0.115513  0.116071  0.115513  0.115513   0.089504   86441600.0
# 4  18-12-1980  0.118862  0.119420  0.118862  0.118862   0.092099   73449600.0

# %%
df1 = pd.DataFrame(apple, columns=['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'])
df1['Date'] = pd.to_datetime(df1['Date'], format='%d-%m-%Y')
df1['Date'] = df1['Date'].dt.strftime('%Y-%m-%d')
df1.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close       Volume
# 0  1980-12-12  0.128348  0.128906  0.128348  0.128348   0.099450  469033600.0
# 1  1980-12-15  0.122210  0.122210  0.121652  0.121652   0.094261  175884800.0
# 2  1980-12-16  0.113281  0.113281  0.112723  0.112723   0.087343  105728000.0
# 3  1980-12-17  0.115513  0.116071  0.115513  0.115513   0.089504   86441600.0
# 4  1980-12-18  0.118862  0.119420  0.118862  0.118862   0.092099   73449600.0

# %%
df1 = df1.loc[df1['Date'] > '2010-01-01']
df1.set_index('Date', inplace=True)
df1
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04    7.622500    7.660714    7.585000    7.643214    6.487534
# 2010-01-05    7.664286    7.699643    7.616071    7.656429    6.498749
# 2010-01-06    7.656429    7.686786    7.526786    7.534643    6.395380
# 2010-01-07    7.562500    7.571429    7.466071    7.520714    6.383555
# 2010-01-08    7.510714    7.571429    7.466429    7.570714    6.425996
# ...                ...         ...         ...         ...         ...
# 2023-09-26  174.820007  175.199997  171.660004  171.960007  171.960007
# 2023-09-27  172.619995  173.039993  169.050003  170.429993  170.429993
# 2023-09-28  169.339996  172.029999  167.619995  170.690002  170.690002
# 2023-09-29  172.020004  173.070007  170.339996  171.210007  171.210007
# 2023-10-02  171.220001  174.300003  170.929993  173.750000  173.750000
#
#                  Volume
# Date
# 2010-01-04  493729600.0
# 2010-01-05  601904800.0
# 2010-01-06  552160000.0
# ...

# %%
amazon = pd.read_csv('Assets/AMZN_data_1999_2022.csv')
amazon.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close      Volume
# 0  1999-01-04  2.730729  2.966667  2.665625  2.957813   2.957813   785844000
# 1  1999-01-05  2.739063  3.243750  2.662500  3.112500   3.112500  1257464000
# 2  1999-01-06  3.409375  3.509375  3.350000  3.450000   3.450000   723532000
# 3  1999-01-07  3.428125  4.006250  3.325000  3.971875   3.971875   945492000
# 4  1999-01-08  4.606250  4.978125  3.800000  4.006250   4.006250  1333244000

# %%
df2 = pd.DataFrame(amazon, columns=['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'])
df2 = df2.loc[df2['Date'] > '2010-01-01']
df2.set_index('Date', inplace=True)
df2
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2010-01-04   6.812500   6.830500   6.657000   6.695000   6.695000  151998000
# 2010-01-05   6.671500   6.774000   6.590500   6.734500   6.734500  177038000
# 2010-01-06   6.730000   6.736500   6.582500   6.612500   6.612500  143576000
# 2010-01-07   6.600500   6.616000   6.440000   6.500000   6.500000  220604000
# 2010-01-08   6.528000   6.684000   6.451500   6.676000   6.676000  196610000
# ...               ...        ...        ...        ...        ...        ...
# 2022-12-23  83.250000  85.779999  82.930000  85.250000  85.250000   57433700
# 2022-12-27  84.970001  85.349998  83.000000  83.040001  83.040001   57284000
# 2022-12-28  82.800003  83.480003  81.690002  81.820000  81.820000   58228600
# 2022-12-29  82.870003  84.550003  82.550003  84.180000  84.180000   54995900
# 2022-12-30  83.120003  84.050003  82.470001  84.000000  84.000000   62401200
#
# [3272 rows x 6 columns]

# %%
microsoft = pd.read_csv('Assets/MSFT(2000-2023).csv')
microsoft
df3 = pd.DataFrame(microsoft, columns=['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'])
df3['Date'] = pd.to_datetime(df3['Date'], format='%m/%d/%Y')
df3['Date'] = df3['Date'].dt.strftime('%Y-%m-%d')
df3.head()
# Out:
#          Date      Open     High       Low     Close  Adj Close    Volume
# 0  2000-01-03  58.68750  59.3125  56.00000  58.28125  36.132248  53228400
# 1  2000-01-04  56.78125  58.5625  56.12500  56.31250  34.911709  54119000
# 2  2000-01-05  55.56250  58.1875  54.68750  56.90625  35.279816  64059600
# 3  2000-01-06  56.09375  56.9375  54.18750  55.00000  34.098019  54976600
# 4  2000-01-07  54.31250  56.1250  53.65625  55.71875  34.543629  62013600

# %%
df3 = df3.loc[df3['Date'] > '2010-01-01']
df3.set_index('Date', inplace=True)
df3
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04   30.620001   31.100000   30.590000   30.950001   23.474922
# 2010-01-05   30.850000   31.100000   30.639999   30.959999   23.482502
# 2010-01-06   30.879999   31.080000   30.520000   30.770000   23.338396
# 2010-01-07   30.629999   30.700001   30.190001   30.450001   23.095678
# 2010-01-08   30.280001   30.879999   30.240000   30.660000   23.254963
# ...                ...         ...         ...         ...         ...
# 2023-11-16  370.959991  376.350006  370.179993  376.170013  376.170013
# 2023-11-17  373.609985  374.369995  367.000000  369.850006  369.850006
# 2023-11-20  371.220001  378.869995  371.000000  377.440002  377.440002
# 2023-11-21  375.670013  376.220001  371.119995  373.070007  373.070007
# 2023-11-22  378.000000  379.790009  374.970001  377.850006  377.850006
#
#               Volume
# Date
# 2010-01-04  38409100
# 2010-01-05  49749600
# 2010-01-06  58182400
# ...

# %%
tesla = pd.read_csv('Assets/tesla_stocks.csv')
tesla
df4 = pd.DataFrame(tesla, columns=['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'])
df4.set_index('Date', inplace=True)
df4
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2023-08-03  252.039993  260.489990  252.000000  259.320007  259.320007
# 2023-08-04  260.970001  264.769989  253.110001  253.860001  253.860001
# 2023-08-07  251.449997  253.649994  242.759995  251.449997  251.449997
# 2023-08-08  247.449997  250.919998  245.009995  249.699997  249.699997
# 2023-08-09  250.869995  251.100006  241.899994  242.190002  242.190002
#
#                Volume
# Date
# 2010-06-29  281494500
# 2010-06-30  257806500
# 2010-07-01  123282000
# ...

# %%
fig = px.histogram(df1, 
                   x='Close', 
                   marginal='box', 
                   nbins=47, 
                   title='Distribution of Close')
fig.update_layout(bargap=0.1)
fig.show()

# %%
fig = px.histogram(df1, 
                   x='Open', 
                   marginal='box', 
                   color_discrete_sequence=['red'], 
                   title='Distribution of open')
fig.update_layout(bargap=0.1)
fig.show()

# %%
fig = px.scatter(df1, 
                 x='Open', 
                 y='Close', 
                 
                 opacity=0.8, 
                  
                 title='Open vs. Close')
fig.update_traces(marker_size=5)
fig.show()

# %%
df1['2010':'2023'].plot(subplots=True, figsize=(10,12))
plt.title('Apple stock attributes from 2010 to 2023')
plt.xlabel('Dates')
plt.show()

# %%
df2['2010':'2023'].plot(subplots=True, figsize=(10,12))
plt.title('Amazon stock attributes from 2010 to 2023')
plt.xlabel('Dates')
plt.show()

# %%
df3['2010':'2023'].plot(subplots=True, figsize=(10,12))
plt.title('Microsoft stock attributes from 2010 to 2023')
plt.xlabel('Dates')
plt.show()

# %%
df4['2010':'2023'].plot(subplots=True, figsize=(10,12))
plt.title('Tesla stock attributes from 2010 to 2023')
plt.xlabel('Dates')
plt.show()

# %%
df1.High.plot(figsize=(20, 5))
df2.High.plot()
df3.High.plot()
df4.High.plot()
plt.legend(['Apple','Amazon','Microsoft','Tesla'])
plt.show()
