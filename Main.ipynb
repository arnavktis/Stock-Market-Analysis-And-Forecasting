# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# Out:
# /var/folders/l1/935tvh5j32742dmcszp1gq0h0000gn/T/ipykernel_27250/67360579.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
apple = pd.read_csv('/Users/arnavkhanna/Documents/GitHub/Stock-Market-Analysis-And-Forecasting-Using-Deep-Learning/Assets/AAPL.csv', index_col='Date', parse_dates=['Date'])
apple.drop('Day Difference', inplace=True, axis=1) 
apple.head()
# Out:
#                 Open      High       Low     Close  Adj Close       Volume
# Date
# 12-12-1980  0.128348  0.128906  0.128348  0.128348   0.099450  469033600.0
# 15-12-1980  0.122210  0.122210  0.121652  0.121652   0.094261  175884800.0
# 16-12-1980  0.113281  0.113281  0.112723  0.112723   0.087343  105728000.0
# 17-12-1980  0.115513  0.116071  0.115513  0.115513   0.089504   86441600.0
# 18-12-1980  0.118862  0.119420  0.118862  0.118862   0.092099   73449600.0

# %%
amazon = pd.read_csv('/Users/arnavkhanna/Documents/GitHub/Stock-Market-Analysis-And-Forecasting-Using-Deep-Learning/Assets/AMZN_data_1999_2022.csv', index_col='Date', parse_dates=['Date'])
amazon.head()
# Out:
#                 Open      High       Low     Close  Adj Close      Volume
# Date
# 1999-01-04  2.730729  2.966667  2.665625  2.957813   2.957813   785844000
# 1999-01-05  2.739063  3.243750  2.662500  3.112500   3.112500  1257464000
# 1999-01-06  3.409375  3.509375  3.350000  3.450000   3.450000   723532000
# 1999-01-07  3.428125  4.006250  3.325000  3.971875   3.971875   945492000
# 1999-01-08  4.606250  4.978125  3.800000  4.006250   4.006250  1333244000

# %%
microsoft = pd.read_csv('/Users/arnavkhanna/Documents/GitHub/Stock-Market-Analysis-And-Forecasting-Using-Deep-Learning/Assets/MSFT(2000-2023).csv', index_col='Date', parse_dates=['Date'])
microsoft.head()
# Out:
#                 Open     High       Low     Close  Adj Close    Volume
# Date
# 2000-01-03  58.68750  59.3125  56.00000  58.28125  36.132248  53228400
# 2000-01-04  56.78125  58.5625  56.12500  56.31250  34.911709  54119000
# 2000-01-05  55.56250  58.1875  54.68750  56.90625  35.279816  64059600
# 2000-01-06  56.09375  56.9375  54.18750  55.00000  34.098019  54976600
# 2000-01-07  54.31250  56.1250  53.65625  55.71875  34.543629  62013600

# %%
tesla = pd.read_csv('/Users/arnavkhanna/Documents/GitHub/Stock-Market-Analysis-And-Forecasting-Using-Deep-Learning/Assets/tesla_stocks.csv', index_col='Date', parse_dates=['Date'])
tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
apple.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  10791.000000  10791.000000  10791.000000  10791.000000  10791.000000
# mean      19.113833     19.326299     18.908083     19.124988     18.394861
# std       40.156308     40.614073     39.724960     40.186661     39.808498
# min        0.049665      0.049665      0.049107      0.049107      0.038050
# 25%        0.292411      0.300469      0.285536      0.292411      0.240748
# 50%        0.504464      0.513393      0.495536      0.504464      0.414394
# 75%       18.555357     18.717322     18.412857     18.569287     16.091877
# max      196.240005    198.229996    195.279999    196.449997    196.185074
#
#              Volume
# count  1.079100e+04
# mean   3.230263e+08
# std    3.367116e+08
# min    0.000000e+00
# 25%    1.175944e+08
# 50%    2.107616e+08
# 75%    4.030152e+08
# max    7.421641e+09

# %%
apple.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10791 entries, 12-12-1980 to 02-10-2023
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       10791 non-null  float64
#  1   High       10791 non-null  float64
#  2   Low        10791 non-null  float64
#  3   Close      10791 non-null  float64
#  4   Adj Close  10791 non-null  float64
#  5   Volume     10791 non-null  float64
# dtypes: float64(6)
# memory usage: 590.1+ KB

# %%
apple.isna().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
microsoft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6012 entries, 2000-01-03 to 2023-11-22
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       6012 non-null   float64
#  1   High       6012 non-null   float64
#  2   Low        6012 non-null   float64
#  3   Close      6012 non-null   float64
#  4   Adj Close  6012 non-null   float64
#  5   Volume     6012 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 328.8 KB

# %%
microsoft.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
microsoft.isna().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6039 entries, 1999-01-04 to 2022-12-30
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       6039 non-null   float64
#  1   High       6039 non-null   float64
#  2   Low        6039 non-null   float64
#  3   Close      6039 non-null   float64
#  4   Adj Close  6039 non-null   float64
#  5   Volume     6039 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 330.3 KB

# %%
amazon.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  6039.000000  6039.000000  6039.000000  6039.000000  6039.000000
# mean     33.032739    33.424013    32.598322    33.016059    33.016059
# std      48.808735    49.374865    48.170554    48.767219    48.767219
# min       0.295500     0.305000     0.275500     0.298500     0.298500
# 25%       2.267000     2.303500     2.226000     2.264250     2.264250
# 50%       8.675000     8.758500     8.576500     8.685500     8.685500
# 75%      41.047501    41.131498    40.737999    40.933750    40.933750
# max     187.199997   188.654007   184.839493   186.570496   186.570496
#
#              Volume
# count  6.039000e+03
# mean   1.334297e+08
# std    1.147912e+08
# min    1.762600e+07
# 25%    6.955200e+07
# 50%    1.054160e+08
# 75%    1.560990e+08
# max    2.086584e+09

# %%
amazon.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
amazon.isna().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
tesla.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  3301.000000  3301.000000  3301.000000  3301.000000  3301.000000
# mean     65.368224    66.828575    63.782962    65.343448    65.343448
# std      98.550565   100.786787    96.061222    98.456444    98.456444
# min       1.076000     1.108667     0.998667     1.053333     1.053333
# 25%       9.948000    10.146000     9.730000     9.865333     9.865333
# 50%      16.656668    16.897333    16.406668    16.666000    16.666000
# 75%      53.333332    54.804668    52.210667    53.335335    53.335335
# max     411.470001   414.496674   405.666656   409.970001   409.970001
#
#              Volume
# count  3.301000e+03
# mean   9.614467e+07
# std    8.108408e+07
# min    1.777500e+06
# 25%    4.472250e+07
# 50%    7.926450e+07
# 75%    1.226595e+08
# max    9.140820e+08

# %%
tesla.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
tesla.isna().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
fig = px.histogram(apple, 
                   x='Close', 
                   marginal='box', 
                   nbins=47, 
                   color_discrete_sequence=['red'],
                   title='Distribution of Close')
fig.update_layout(bargap=0.1)
fig.show()

# %%
fig = px.histogram(apple, 
                   x='Open', 
                   marginal='box', 
                   color_discrete_sequence=['red'], 
                   title='Distribution of open')
fig.update_layout(bargap=0.1)
fig.show()

# %%
fig = px.scatter(apple, 
                 x='Open', 
                 y='Close', 
                 
                 opacity=0.8, 
                  
                 title='Open vs. Close')
fig.update_traces(marker_size=5)
fig.show()

# %%
apple.corr()
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.999944  0.999932  0.999859   0.999615 -0.234278
# High       0.999944  1.000000  0.999919  0.999933   0.999699 -0.233843
# Low        0.999932  0.999919  1.000000  0.999936   0.999691 -0.234988
# Close      0.999859  0.999933  0.999936  1.000000   0.999761 -0.234433
# Adj Close  0.999615  0.999699  0.999691  0.999761   1.000000 -0.236455
# Volume    -0.234278 -0.233843 -0.234988 -0.234433  -0.236455  1.000000

# %%
apple['2000':'2021'].plot(subplots=True, figsize=(10,12))
plt.title('Google stock attributes from 2000 to 2020')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2000'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 apple['2000':'2021'].plot(subplots=True, figsize=(10,12))
#       2 plt.title('Google stock attributes from 2000 to 2020')
#       3 plt.show()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:4073, in DataFrame.__getitem__(self, key)
#    4071 # Do we have a slicer (on rows)?
#    4072 if isinstance(key, slice):
# -> 4073     return self._getitem_slice(key)
#    4075 # Do we have a (boolean) DataFrame?
#    4076 if isinstance(key, DataFrame):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py:4343, in NDFrame._getitem_slice(self, key)
#    4338 """
#    4339 __getitem__ for the case where the key is a slice object.
#    4340 """
#    4341 # _convert_slice_indexer to determine if this slice is positional
#    4342 #  or label based, and if the latter, convert to positional
# -> 4343 slobj = self.index._convert_slice_indexer(key, kind="getitem")
#    4344 if isinstance(slobj, np.ndarray):
#    4345     # reachable with DatetimeIndex
#    4346     indexer = lib.maybe_indices_to_slice(
#    4347         slobj.astype(np.intp, copy=False), len(self)
#    4348     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:4278, in Index._convert_slice_indexer(self, key, kind)
#    4276     indexer = key
#    4277 else:
# -> 4278     indexer = self.slice_indexer(start, stop, step)
#    4280 return indexer
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:6661, in Index.slice_indexer(self, start, end, step)
#    6617 def slice_indexer(
#    6618     self,
#    6619     start: Hashable | None = None,
#    6620     end: Hashable | None = None,
#    6621     step: int | None = None,
#    6622 ) -> slice:
#    6623     """
#    6624     Compute the slice indexer for input labels and step.
#    6625
#    (...)
#    6659     slice(1, 3, None)
#    6660     """
# -> 6661     start_slice, end_slice = self.slice_locs(start, end, step=step)
#    6663     # return a slice
#    6664     if not is_scalar(start_slice):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:6878, in Index.slice_locs(self, start, end, step)
#    6876 start_slice = None
#    6877 if start is not None:
# -> 6878     start_slice = self.get_slice_bound(start, "left")
#    6879 if start_slice is None:
#    6880     start_slice = 0
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:6803, in Index.get_slice_bound(self, label, side)
#    6800         return self._searchsorted_monotonic(label, side)
#    6801     except ValueError:
#    6802         # raise the original KeyError
# -> 6803         raise err
#    6805 if isinstance(slc, np.ndarray):
#    6806     # get_loc may return a boolean array, which
#    6807     # is OK as long as they are representable by a slice.
#    6808     assert is_bool_dtype(slc.dtype)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:6797, in Index.get_slice_bound(self, label, side)
#    6795 # we need to look up the label
#    6796 try:
# -> 6797     slc = self.get_loc(label)
#    6798 except KeyError as err:
#    6799     try:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3809, in Index.get_loc(self, key)
#    3804     if isinstance(casted_key, slice) or (
#    3805         isinstance(casted_key, abc.Iterable)
#    3806         and any(isinstance(x, slice) for x in casted_key)
#    3807     ):
#    3808         raise InvalidIndexError(key)
# -> 3809     raise KeyError(key) from err
#    3810 except TypeError:
#    3811     # If we have a listlike key, _check_indexing_error will raise
#    3812     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3813     #  the TypeError.
#    3814     self._check_indexing_error(key)
#
# KeyError: '2000'

# %%
apple.index = pd.to_datetime(apple.index, errors='coerce')

# %%
apple.index = pd.to_datetime(apple.index)
